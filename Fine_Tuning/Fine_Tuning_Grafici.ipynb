# %%
import json

with open('/home/gbarbaro/Test/Inferenza_Fine_Tuning/LLAMA_3.2_Fine_Tuned(Full)/checkpoint-51510/trainer_state.json', 'r') as file:
    data = json.load(file)

import matplotlib.pyplot as plt
import numpy as np

train_epochs = [entry['epoch'] for entry in data['log_history'] if 'loss' in entry]
train_loss = [entry['loss'] for entry in data['log_history'] if 'loss' in entry]
eval_epochs = [entry['epoch'] for entry in data['log_history'] if 'eval_loss' in entry]
eval_loss = [entry['eval_loss'] for entry in data['log_history'] if 'eval_loss' in entry]
train_f1 = [entry['f1_score'] for entry in data['log_history'] if 'f1_score' in entry]
eval_f1 =  [entry['eval_f1_score'] for entry in data['log_history'] if 'eval_f1_score' in entry]

selected_indices = np.linspace(0, len(train_epochs) - 1, 31, dtype=int).tolist() 
selected_train_epochs = [train_epochs[i] for i in selected_indices] 
selected_train_loss = [train_loss[i] for i in selected_indices] 
selected_train_f1 = [train_f1[i] for i in selected_indices]

optimal_epochs = [3]

# Grafico delle perdite
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_loss)], selected_train_loss, label='Train Loss')
plt.plot(eval_epochs[:len(eval_loss)], eval_loss, label='Eval Loss')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('LLAMA 3.2 3B with documents: Train and Eval Loss')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()

# Grafico dei punteggi F1
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_f1)], selected_train_f1, label='Train F1 Score')
plt.plot(eval_epochs[:len(eval_f1)], eval_f1, label='Eval F1 Score')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('LLAMA 3.2 3B with documents: Train and Eval BERT F1 Score')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()
# Out:
# /tmp/ipykernel_3831560/225218316.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
# /tmp/ipykernel_3831560/225218316.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")

# %%
import json

with open('/home/gbarbaro/Test/Inferenza_Fine_Tuning/LLAMA_3.2_Fine_Tuned(Full_No_Doc)/checkpoint-51510/trainer_state.json', 'r') as file:
    data = json.load(file)

import matplotlib.pyplot as plt
import numpy as np

train_epochs = [entry['epoch'] for entry in data['log_history'] if 'loss' in entry]
train_loss = [entry['loss'] for entry in data['log_history'] if 'loss' in entry]
eval_epochs = [entry['epoch'] for entry in data['log_history'] if 'eval_loss' in entry]
eval_loss = [entry['eval_loss'] for entry in data['log_history'] if 'eval_loss' in entry]
train_f1 = [entry['f1_score'] for entry in data['log_history'] if 'f1_score' in entry]
eval_f1 =  [entry['eval_f1_score'] for entry in data['log_history'] if 'eval_f1_score' in entry]

selected_indices = np.linspace(0, len(train_epochs) - 1, 31, dtype=int).tolist() 
selected_train_epochs = [train_epochs[i] for i in selected_indices] 
selected_train_loss = [train_loss[i] for i in selected_indices] 
selected_train_f1 = [train_f1[i] for i in selected_indices]

optimal_epochs = [3]

# Grafico delle perdite
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_loss)], selected_train_loss, label='Train Loss')
plt.plot(eval_epochs[:len(eval_loss)], eval_loss, label='Eval Loss')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('LLAMA 3.2 3B without documents: Train and Eval Loss')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()

# Grafico dei punteggi F1
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_f1)], selected_train_f1, label='Train F1 Score')
plt.plot(eval_epochs[:len(eval_f1)], eval_f1, label='Eval F1 Score')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('LLAMA 3.2 3B without documents: Train and Eval BERT F1 Score')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()
# Out:
# /tmp/ipykernel_3831560/662003447.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
# /tmp/ipykernel_3831560/662003447.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")

# %%
import json

with open('/home/gbarbaro/Test/Inferenza_Fine_Tuning/MINERVA_3B_Fine_Tuned(Full)/checkpoint-51510/trainer_state.json', 'r') as file:
    data = json.load(file)

import matplotlib.pyplot as plt 
import numpy as np

train_epochs = [entry['epoch'] for entry in data['log_history'] if 'loss' in entry]
train_loss = [entry['loss'] for entry in data['log_history'] if 'loss' in entry]
eval_epochs = [entry['epoch'] for entry in data['log_history'] if 'eval_loss' in entry]
eval_loss = [entry['eval_loss'] for entry in data['log_history'] if 'eval_loss' in entry]
train_f1 = [entry['f1_score'] for entry in data['log_history'] if 'f1_score' in entry]
eval_f1 =  [entry['eval_f1_score'] for entry in data['log_history'] if 'eval_f1_score' in entry]

selected_indices = np.linspace(0, len(train_epochs) - 1, 31, dtype=int).tolist() 
selected_train_epochs = [train_epochs[i] for i in selected_indices] 
selected_train_loss = [train_loss[i] for i in selected_indices] 
selected_train_f1 = [train_f1[i] for i in selected_indices]

optimal_epochs = [3]

# Grafico delle perdite
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_loss)], selected_train_loss, label='Train Loss')
plt.plot(eval_epochs[:len(eval_loss)], eval_loss, label='Eval Loss')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('MINERVA 3B with documents: Train and Eval Loss')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()

# Grafico dei punteggi F1
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_f1)], selected_train_f1, label='Train F1 Score')
plt.plot(eval_epochs[:len(eval_f1)], eval_f1, label='Eval F1 Score')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('MINERVA 3B with documents: Train and Eval BERT F1 Score')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()
# Out:
# /tmp/ipykernel_3831560/2795101988.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
# /tmp/ipykernel_3831560/2795101988.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")

# %%
import json

with open('/home/gbarbaro/Test/Inferenza_Fine_Tuning/MINERVA_3B_Fine_Tuned(Full_No_Doc)/checkpoint-51510/trainer_state.json', 'r') as file:
    data = json.load(file)
    
import matplotlib.pyplot as plt
import numpy as np

train_epochs = [entry['epoch'] for entry in data['log_history'] if 'loss' in entry]
train_loss = [entry['loss'] for entry in data['log_history'] if 'loss' in entry]
eval_epochs = [entry['epoch'] for entry in data['log_history'] if 'eval_loss' in entry]
eval_loss = [entry['eval_loss'] for entry in data['log_history'] if 'eval_loss' in entry]
train_f1 = [entry['f1_score'] for entry in data['log_history'] if 'f1_score' in entry]
eval_f1 =  [entry['eval_f1_score'] for entry in data['log_history'] if 'eval_f1_score' in entry]

selected_indices = np.linspace(0, len(train_epochs) - 1, 31, dtype=int).tolist() 
selected_train_epochs = [train_epochs[i] for i in selected_indices] 
selected_train_loss = [train_loss[i] for i in selected_indices] 
selected_train_f1 = [train_f1[i] for i in selected_indices]

optimal_epochs = [2]

# Grafico delle perdite
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_loss)], selected_train_loss, label='Train Loss')
plt.plot(eval_epochs[:len(eval_loss)], eval_loss, label='Eval Loss')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('MINERVA 3B without documents: Train and Eval Loss')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()

# Grafico dei punteggi F1
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_f1)], selected_train_f1, label='Train F1 Score')
plt.plot(eval_epochs[:len(eval_f1)], eval_f1, label='Eval F1 Score')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('MINERVA 3B without documents: Train and Eval BERT F1 Score')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()
# Out:
# /tmp/ipykernel_3831560/4107336396.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
# /tmp/ipykernel_3831560/4107336396.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")

# %%
import json

with open('/home/gbarbaro/Test/Inferenza_Fine_Tuning/PHI_3.5_Fine_Tuned(Full)/checkpoint-51510/trainer_state.json', 'r') as file:
    data = json.load(file)
    
import matplotlib.pyplot as plt
import numpy as np

train_epochs = [entry['epoch'] for entry in data['log_history'] if 'loss' in entry]
train_loss = [entry['loss'] for entry in data['log_history'] if 'loss' in entry]
eval_epochs = [entry['epoch'] for entry in data['log_history'] if 'eval_loss' in entry]
eval_loss = [entry['eval_loss'] for entry in data['log_history'] if 'eval_loss' in entry]
train_f1 = [entry['f1_score'] for entry in data['log_history'] if 'f1_score' in entry]
eval_f1 =  [entry['eval_f1_score'] for entry in data['log_history'] if 'eval_f1_score' in entry]

selected_indices = np.linspace(0, len(train_epochs) - 1, 31, dtype=int).tolist() 
selected_train_epochs = [train_epochs[i] for i in selected_indices] 
selected_train_loss = [train_loss[i] for i in selected_indices] 
selected_train_f1 = [train_f1[i] for i in selected_indices]

optimal_epochs = [2]

# Grafico delle perdite
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_loss)], selected_train_loss, label='Train Loss')
plt.plot(eval_epochs[:len(eval_loss)], eval_loss, label='Eval Loss')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('PHI 3.5 4B with documents: Train and Eval Loss')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()

# Grafico dei punteggi F1
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_f1)], selected_train_f1, label='Train F1 Score')
plt.plot(eval_epochs[:len(eval_f1)], eval_f1, label='Eval F1 Score')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('PHI 3.5 4B with documents: Train and Eval BERT F1 Score')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()
# Out:
# /tmp/ipykernel_829679/3818608915.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
# /tmp/ipykernel_829679/3818608915.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")

# %%
import json

with open('/home/gbarbaro/Test/Inferenza_Fine_Tuning/PHI_3.5_Fine_Tuned(Full_No_Doc)/checkpoint-51510/trainer_state.json', 'r') as file:
    data = json.load(file)
    
import matplotlib.pyplot as plt
import numpy as np

train_epochs = [entry['epoch'] for entry in data['log_history'] if 'loss' in entry]
train_loss = [entry['loss'] for entry in data['log_history'] if 'loss' in entry]
eval_epochs = [entry['epoch'] for entry in data['log_history'] if 'eval_loss' in entry]
eval_loss = [entry['eval_loss'] for entry in data['log_history'] if 'eval_loss' in entry]
train_f1 = [entry['f1_score'] for entry in data['log_history'] if 'f1_score' in entry]
eval_f1 =  [entry['eval_f1_score'] for entry in data['log_history'] if 'eval_f1_score' in entry]

selected_indices = np.linspace(0, len(train_epochs) - 1, 31, dtype=int).tolist() 
selected_train_epochs = [train_epochs[i] for i in selected_indices] 
selected_train_loss = [train_loss[i] for i in selected_indices] 
selected_train_f1 = [train_f1[i] for i in selected_indices]

optimal_epochs = [3]

# Grafico delle perdite
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_loss)], selected_train_loss, label='Train Loss')
plt.plot(eval_epochs[:len(eval_loss)], eval_loss, label='Eval Loss')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('PHI 3.5 4B without documents: Train and Eval Loss')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()

# Grafico dei punteggi F1
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_f1)], selected_train_f1, label='Train F1 Score')
plt.plot(eval_epochs[:len(eval_f1)], eval_f1, label='Eval F1 Score')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('PHI 3.5 4B without documents: Train and Eval BERT F1 Score')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()
# Out:
# /tmp/ipykernel_829679/3694784597.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
# /tmp/ipykernel_829679/3694784597.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")

# %%
import json

with open('/home/gbarbaro/Test/Inferenza_Fine_Tuning/QWEN2_Fine_Tuned(Full)/trainer_state.json', 'r') as file:
    data = json.load(file)
    
import matplotlib.pyplot as plt
import numpy as np

train_epochs = [entry['epoch'] for entry in data['log_history'] if 'loss' in entry]
train_loss = [entry['loss'] for entry in data['log_history'] if 'loss' in entry]
eval_epochs = [entry['epoch'] for entry in data['log_history'] if 'eval_loss' in entry]
eval_loss = [entry['eval_loss'] for entry in data['log_history'] if 'eval_loss' in entry]
train_f1 = [entry['f1_score'] for entry in data['log_history'] if 'f1_score' in entry]
eval_f1 =  [entry['eval_f1_score'] for entry in data['log_history'] if 'eval_f1_score' in entry]

selected_indices = np.linspace(0, len(train_epochs) - 1, 31, dtype=int).tolist() 
selected_train_epochs = [train_epochs[i] for i in selected_indices] 
selected_train_loss = [train_loss[i] for i in selected_indices] 
selected_train_f1 = [train_f1[i] for i in selected_indices]

optimal_epochs = [3]

# Grafico delle perdite
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_loss)], selected_train_loss, label='Train Loss')
plt.plot(eval_epochs[:len(eval_loss)], eval_loss, label='Eval Loss')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('QWEN 2 7B with documents: Train and Eval Loss')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()

# Grafico dei punteggi F1
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_f1)], selected_train_f1, label='Train F1 Score')
plt.plot(eval_epochs[:len(eval_f1)], eval_f1, label='Eval F1 Score')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('QWEN 2 7B with documents: Train and Eval BERT F1 Score')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()
# Out:
# /tmp/ipykernel_829679/3174370688.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
# /tmp/ipykernel_829679/3174370688.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")

# %%
import json

with open('/home/gbarbaro/Test/Inferenza_Fine_Tuning/QWEN2_Fine_Tuned(Full_No_Doc)/trainer_state.json', 'r') as file:
    data = json.load(file)
    
import matplotlib.pyplot as plt
import numpy as np

train_epochs = [entry['epoch'] for entry in data['log_history'] if 'loss' in entry]
train_loss = [entry['loss'] for entry in data['log_history'] if 'loss' in entry]
eval_epochs = [entry['epoch'] for entry in data['log_history'] if 'eval_loss' in entry]
eval_loss = [entry['eval_loss'] for entry in data['log_history'] if 'eval_loss' in entry]
train_f1 = [entry['f1_score'] for entry in data['log_history'] if 'f1_score' in entry]
eval_f1 =  [entry['eval_f1_score'] for entry in data['log_history'] if 'eval_f1_score' in entry]

selected_indices = np.linspace(0, len(train_epochs) - 1, 31, dtype=int).tolist() 
selected_train_epochs = [train_epochs[i] for i in selected_indices] 
selected_train_loss = [train_loss[i] for i in selected_indices] 
selected_train_f1 = [train_f1[i] for i in selected_indices]

optimal_epochs = [2]

# Grafico delle perdite
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_loss)], selected_train_loss, label='Train Loss')
plt.plot(eval_epochs[:len(eval_loss)], eval_loss, label='Eval Loss')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('QWEN 2 7B without documents: Train and Eval Loss')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()

# Grafico dei punteggi F1
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_f1)], selected_train_f1, label='Train F1 Score')
plt.plot(eval_epochs[:len(eval_f1)], eval_f1, label='Eval F1 Score')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('QWEN 2 7B without documents: Train and Eval BERT F1 Score')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()
# Out:
# /tmp/ipykernel_829679/966074705.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
# /tmp/ipykernel_829679/966074705.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")

# %%
import json

with open('/home/gbarbaro/Test/Inferenza_Fine_Tuning/OCCIGLOT_Fine_Tuned(Full)/trainer_state.json', 'r') as file:
    data = json.load(file)
    
import matplotlib.pyplot as plt
import numpy as np

train_epochs = [entry['epoch'] for entry in data['log_history'] if 'loss' in entry]
train_loss = [entry['loss'] for entry in data['log_history'] if 'loss' in entry]
eval_epochs = [entry['epoch'] for entry in data['log_history'] if 'eval_loss' in entry]
eval_loss = [entry['eval_loss'] for entry in data['log_history'] if 'eval_loss' in entry]
train_f1 = [entry['f1_score'] for entry in data['log_history'] if 'f1_score' in entry]
eval_f1 =  [entry['eval_f1_score'] for entry in data['log_history'] if 'eval_f1_score' in entry]

selected_indices = np.linspace(0, len(train_epochs) - 1, 31, dtype=int).tolist() 
selected_train_epochs = [train_epochs[i] for i in selected_indices] 
selected_train_loss = [train_loss[i] for i in selected_indices] 
selected_train_f1 = [train_f1[i] for i in selected_indices]

optimal_epochs = [3]

# Grafico delle perdite
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_loss)], selected_train_loss, label='Train Loss')
plt.plot(eval_epochs[:len(eval_loss)], eval_loss, label='Eval Loss')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('OCCIGLOT 7B with documents: Train and Eval Loss')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()

# Grafico dei punteggi F1
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_f1)], selected_train_f1, label='Train F1 Score')
plt.plot(eval_epochs[:len(eval_f1)], eval_f1, label='Eval F1 Score')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('OCCIGLOT 7B with documents: Train and Eval BERT F1 Score')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()
# Out:
# /tmp/ipykernel_829679/2640971933.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
# /tmp/ipykernel_829679/2640971933.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")

# %%
import json

with open('/home/gbarbaro/Test/Inferenza_Fine_Tuning/OCCIGLOT_Fine_Tuned(Full_No_Doc)/trainer_state.json', 'r') as file:
    data = json.load(file)
    
import matplotlib.pyplot as plt
import numpy as np

train_epochs = [entry['epoch'] for entry in data['log_history'] if 'loss' in entry]
train_loss = [entry['loss'] for entry in data['log_history'] if 'loss' in entry]
eval_epochs = [entry['epoch'] for entry in data['log_history'] if 'eval_loss' in entry]
eval_loss = [entry['eval_loss'] for entry in data['log_history'] if 'eval_loss' in entry]
train_f1 = [entry['f1_score'] for entry in data['log_history'] if 'f1_score' in entry]
eval_f1 =  [entry['eval_f1_score'] for entry in data['log_history'] if 'eval_f1_score' in entry]

selected_indices = np.linspace(0, len(train_epochs) - 1, 31, dtype=int).tolist() 
selected_train_epochs = [train_epochs[i] for i in selected_indices] 
selected_train_loss = [train_loss[i] for i in selected_indices] 
selected_train_f1 = [train_f1[i] for i in selected_indices]

optimal_epochs = [4]

# Grafico delle perdite
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_loss)], selected_train_loss, label='Train Loss')
plt.plot(eval_epochs[:len(eval_loss)], eval_loss, label='Eval Loss')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('OCCIGLOT 7B without documents: Train and Eval Loss')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()

# Grafico dei punteggi F1
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_f1)], selected_train_f1, label='Train F1 Score')
plt.plot(eval_epochs[:len(eval_f1)], eval_f1, label='Eval F1 Score')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('OCCIGLOT 7B without documents: Train and Eval BERT F1 Score')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()
# Out:
# /tmp/ipykernel_829679/2880433585.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
# /tmp/ipykernel_829679/2880433585.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")

# %%
import json

with open('/home/gbarbaro/Test/Inferenza_Fine_Tuning/GEMMA_2_Fine_Tuned(Peft_Full)/trainer_state.json', 'r') as file:
    data = json.load(file)
    
import matplotlib.pyplot as plt
import numpy as np

train_epochs = [entry['epoch'] for entry in data['log_history'] if 'loss' in entry]
train_loss = [entry['loss'] for entry in data['log_history'] if 'loss' in entry]
eval_epochs = [entry['epoch'] for entry in data['log_history'] if 'eval_loss' in entry]
eval_loss = [entry['eval_loss'] for entry in data['log_history'] if 'eval_loss' in entry]
train_f1 = [entry['f1_score'] for entry in data['log_history'] if 'f1_score' in entry]
eval_f1 =  [entry['eval_f1_score'] for entry in data['log_history'] if 'eval_f1_score' in entry]

selected_indices = np.linspace(0, len(train_epochs) - 1, 31, dtype=int).tolist() 
selected_train_epochs = [train_epochs[i] for i in selected_indices] 
selected_train_loss = [train_loss[i] for i in selected_indices] 
selected_train_f1 = [train_f1[i] for i in selected_indices]

optimal_epochs = [5]

# Grafico delle perdite
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_loss)], selected_train_loss, label='Train Loss')
plt.plot(eval_epochs[:len(eval_loss)], eval_loss, label='Eval Loss')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('GEMMA 2 9B with documents: Train and Eval Loss')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()

# Grafico dei punteggi F1
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_f1)], selected_train_f1, label='Train F1 Score')
plt.plot(eval_epochs[:len(eval_f1)], eval_f1, label='Eval F1 Score')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('GEMMA 2 9B with documents: Train and Eval BERT F1 Score')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()
# Out:
# /tmp/ipykernel_16560/1531084923.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
# /tmp/ipykernel_16560/1531084923.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")

# %%
import json

with open('/home/gbarbaro/Test/Inferenza_Fine_Tuning/GEMMA_2_Fine_Tuned(Peft_Full_No_Doc)/trainer_state.json', 'r') as file:
    data = json.load(file)
    
import matplotlib.pyplot as plt
import numpy as np

train_epochs = [entry['epoch'] for entry in data['log_history'] if 'loss' in entry]
train_loss = [entry['loss'] for entry in data['log_history'] if 'loss' in entry]
eval_epochs = [entry['epoch'] for entry in data['log_history'] if 'eval_loss' in entry]
eval_loss = [entry['eval_loss'] for entry in data['log_history'] if 'eval_loss' in entry]
train_f1 = [entry['f1_score'] for entry in data['log_history'] if 'f1_score' in entry]
eval_f1 =  [entry['eval_f1_score'] for entry in data['log_history'] if 'eval_f1_score' in entry]

selected_indices = np.linspace(0, len(train_epochs) - 1, 31, dtype=int).tolist() 
selected_train_epochs = [train_epochs[i] for i in selected_indices] 
selected_train_loss = [train_loss[i] for i in selected_indices] 
selected_train_f1 = [train_f1[i] for i in selected_indices]

optimal_epochs = [3]

# Grafico delle perdite
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_loss)], selected_train_loss, label='Train Loss')
plt.plot(eval_epochs[:len(eval_loss)], eval_loss, label='Eval Loss')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('GEMMA 2 9B without documents: Train and Eval Loss')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()

# Grafico dei punteggi F1
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_f1)], selected_train_f1, label='Train F1 Score')
plt.plot(eval_epochs[:len(eval_f1)], eval_f1, label='Eval F1 Score')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('GEMMA 2 9B without documents: Train and Eval BERT F1 Score')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()
# Out:
# /tmp/ipykernel_1819168/1818622150.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
# /tmp/ipykernel_1819168/1818622150.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")

# %%
import json

with open('/home/gbarbaro/Test/Inferenza_Fine_Tuning/MIXTRAL_Fine_Tuned(Peft_Full_No_Doc)/trainer_state.json', 'r') as file:
    data = json.load(file)
    
import matplotlib.pyplot as plt
import numpy as np

train_epochs = [entry['epoch'] for entry in data['log_history'] if 'loss' in entry]
train_loss = [entry['loss'] for entry in data['log_history'] if 'loss' in entry]
eval_epochs = [entry['epoch'] for entry in data['log_history'] if 'eval_loss' in entry]
eval_loss = [entry['eval_loss'] for entry in data['log_history'] if 'eval_loss' in entry]
train_f1 = [entry['f1_score'] for entry in data['log_history'] if 'f1_score' in entry]
eval_f1 =  [entry['eval_f1_score'] for entry in data['log_history'] if 'eval_f1_score' in entry]

selected_indices = np.linspace(0, len(train_epochs) - 1, 31, dtype=int).tolist() 
selected_train_epochs = [train_epochs[i] for i in selected_indices] 
selected_train_loss = [train_loss[i] for i in selected_indices] 
selected_train_f1 = [train_f1[i] for i in selected_indices]

optimal_epochs = [3]

# Grafico delle perdite
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_loss)], selected_train_loss, label='Train Loss')
plt.plot(eval_epochs[:len(eval_loss)], eval_loss, label='Eval Loss')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('MIXTRAL 45B without documents: Train and Eval Loss')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()

# Grafico dei punteggi F1
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_f1)], selected_train_f1, label='Train F1 Score')
plt.plot(eval_epochs[:len(eval_f1)], eval_f1, label='Eval F1 Score')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('MIXTRAL 45B without documents: Train and Eval BERT F1 Score')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()
# Out:
# /tmp/ipykernel_179258/1528091155.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
# /tmp/ipykernel_179258/1528091155.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")

# %%
import json

with open('/home/gbarbaro/Test/Inferenza_Fine_Tuning/MIXTRAL_Fine_Tuned(Peft_Full)/trainer_state.json', 'r') as file:
    data = json.load(file)
    
import matplotlib.pyplot as plt
import numpy as np

train_epochs = [entry['epoch'] for entry in data['log_history'] if 'loss' in entry]
train_loss = [entry['loss'] for entry in data['log_history'] if 'loss' in entry]
eval_epochs = [entry['epoch'] for entry in data['log_history'] if 'eval_loss' in entry]
eval_loss = [entry['eval_loss'] for entry in data['log_history'] if 'eval_loss' in entry]
train_f1 = [entry['f1_score'] for entry in data['log_history'] if 'f1_score' in entry]
eval_f1 =  [entry['eval_f1_score'] for entry in data['log_history'] if 'eval_f1_score' in entry]

selected_indices = np.linspace(0, len(train_epochs) - 1, 31, dtype=int).tolist() 
selected_train_epochs = [train_epochs[i] for i in selected_indices] 
selected_train_loss = [train_loss[i] for i in selected_indices] 
selected_train_f1 = [train_f1[i] for i in selected_indices]

optimal_epochs = [6]

# Grafico delle perdite
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_loss)], selected_train_loss, label='Train Loss')
plt.plot(eval_epochs[:len(eval_loss)], eval_loss, label='Eval Loss')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('MIXTRAL 45B with documents: Train and Eval Loss')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()

# Grafico dei punteggi F1
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_f1)], selected_train_f1, label='Train F1 Score')
plt.plot(eval_epochs[:len(eval_f1)], eval_f1, label='Eval F1 Score')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('MIXTRAL 45B with documents: Train and Eval BERT F1 Score')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()
# Out:
# /tmp/ipykernel_875730/4276901056.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
# /tmp/ipykernel_875730/4276901056.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")

# %%
import json

with open('/home/gbarbaro/Test/Inferenza_Fine_Tuning/LLAMA_3.3_Fine_Tuned(Peft_Full_No_Doc)/trainer_state.json', 'r') as file:
    data = json.load(file)
    
import matplotlib.pyplot as plt
import numpy as np

train_epochs = [entry['epoch'] for entry in data['log_history'] if 'loss' in entry]
train_loss = [entry['loss'] for entry in data['log_history'] if 'loss' in entry]
eval_epochs = [entry['epoch'] for entry in data['log_history'] if 'eval_loss' in entry]
eval_loss = [entry['eval_loss'] for entry in data['log_history'] if 'eval_loss' in entry]
train_f1 = [entry['f1_score'] for entry in data['log_history'] if 'f1_score' in entry]
eval_f1 =  [entry['eval_f1_score'] for entry in data['log_history'] if 'eval_f1_score' in entry]

selected_indices = np.linspace(0, len(train_epochs) - 1, 31, dtype=int).tolist() 
selected_train_epochs = [train_epochs[i] for i in selected_indices] 
selected_train_loss = [train_loss[i] for i in selected_indices] 
selected_train_f1 = [train_f1[i] for i in selected_indices]

optimal_epochs = [4]

# Grafico delle perdite
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_loss)], selected_train_loss, label='Train Loss')
plt.plot(eval_epochs[:len(eval_loss)], eval_loss, label='Eval Loss')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('LLAMA 3.3 70B without documents: Train and Eval Loss')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()

# Grafico dei punteggi F1
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_f1)], selected_train_f1, label='Train F1 Score')
plt.plot(eval_epochs[:len(eval_f1)], eval_f1, label='Eval F1 Score')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('LLAMA 3.3 70B without documents: Train and Eval BERT F1 Score')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()
# Out:
# /tmp/ipykernel_179258/2695245340.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
# /tmp/ipykernel_179258/2695245340.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")

# %%
import json

with open('/home/gbarbaro/Test/Inferenza_Fine_Tuning/LLAMA_3.3_Fine_Tuned(Peft_Full)/trainer_state.json', 'r') as file:
    data = json.load(file)
    
import matplotlib.pyplot as plt
import numpy as np

train_epochs = [entry['epoch'] for entry in data['log_history'] if 'loss' in entry]
train_loss = [entry['loss'] for entry in data['log_history'] if 'loss' in entry]
eval_epochs = [entry['epoch'] for entry in data['log_history'] if 'eval_loss' in entry]
eval_loss = [entry['eval_loss'] for entry in data['log_history'] if 'eval_loss' in entry]
train_f1 = [entry['f1_score'] for entry in data['log_history'] if 'f1_score' in entry]
eval_f1 =  [entry['eval_f1_score'] for entry in data['log_history'] if 'eval_f1_score' in entry]

selected_indices = np.linspace(0, len(train_epochs) - 1, 31, dtype=int).tolist() 
selected_train_epochs = [train_epochs[i] for i in selected_indices] 
selected_train_loss = [train_loss[i] for i in selected_indices] 
selected_train_f1 = [train_f1[i] for i in selected_indices]

optimal_epochs = [3]

# Grafico delle perdite
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_loss)], selected_train_loss, label='Train Loss')
plt.plot(eval_epochs[:len(eval_loss)], eval_loss, label='Eval Loss')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('LLAMA 3.3 70B with documents: Train and Eval Loss')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()

# Grafico dei punteggi F1
plt.figure(figsize=(12, 6))
plt.plot(selected_train_epochs[:len(train_f1)], selected_train_f1, label='Train F1 Score')
plt.plot(eval_epochs[:len(eval_f1)], eval_f1, label='Eval F1 Score')
for epoch in optimal_epochs: 
    plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('LLAMA 3.3 70B with documents: Train and Eval BERT F1 Score')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)
plt.show()
# Out:
# /tmp/ipykernel_190431/2838602364.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_loss[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
# /tmp/ipykernel_190431/2838602364.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epoch, eval_f1[eval_epochs.index(epoch)], 'go', markersize=12, label=f'Optimal Epoch {epoch}', color="lime")
